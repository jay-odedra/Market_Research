# %%
import sys
import sys
sys.path.append("D:/Documents/Market_Research/Market_Research_exploration") 
from Market_Research_helper.dataset import get_stock_dataset
from Market_Research_helper.functions import get_return_Ndays
import datetime as dt
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.offline as pyo
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pyo.init_notebook_mode(connected=True)
pd.options.plotting.backend = "plotly"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
df = get_stock_dataset('BARC.L', end_date=[2024, 1, 1], days=3650)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2025-02-20 01:34:36.388 | INFO     | Market_Research_helper.dataset:get_stock_dataset:27 - Loading BARC.L data from 2014-01-03 00:00:00 to [2024, 1, 1].
# 2025-02-20 01:34:36.511 | SUCCESS  | Market_Research_helper.dataset:get_stock_dataset:29 - Success loading BARC.L data.
# Price            Close        High         Low        Open    Volume
# Date
# 2014-01-03  201.113754  201.895063  199.307886  199.934413  23678963
# 2014-01-06  204.541229  205.401402  199.897600  200.155561  47008835
# 2014-01-07  207.084167  208.431562  202.698500  204.135826  44374624
# 2014-01-08  209.111115  210.732689  207.305246  208.116045  45068534
# 2014-01-09  209.627121  213.541786  208.210445  209.258578  57522092
# ...                ...         ...         ...         ...       ...
# 2023-12-21  144.749130  145.838907  142.321037  143.429922  55268216
# 2023-12-22  145.093246  145.380033  143.276958  143.296066  13070297
# ...

# %%
log_return = get_return_Ndays(df, 1, log=True)
log_return
# Out:
# 2025-02-20 01:34:36.543 | INFO     | Market_Research_helper.functions:get_return_Ndays:21 - Computing log return over 1
# Date
# 2014-01-06    0.016899
# 2014-01-07    0.012356
# 2014-01-08    0.009740
# 2014-01-09    0.002465
# 2014-01-10   -0.002817
#                 ...
# 2023-12-21   -0.001452
# 2023-12-22    0.002375
# 2023-12-27    0.012310
# 2023-12-28   -0.001042
# 2023-12-29    0.001822
# Name: LOGRTN_D1, Length: 2523, dtype: float64

# %%
daily_std = log_return.std()
daily_std
# Out:
# np.float64(0.02156542871124303)

# %%
annualized_vol = daily_std * np.sqrt(252)
annualized_vol*100
# Out:
# np.float64(34.23405677186473)

# %%
trading_days = 60
volatility = log_return.rolling(window=trading_days,min_periods=1).std() * np.sqrt(trading_days)
volatility.plot().update_layout(autosize=True)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Rf = 0.01/252
sharpe_ratio = (log_return.rolling(window=trading_days,min_periods=10).mean() - Rf)*trading_days / volatility

# %%
sharpe_ratio.plot().update_layout(autosize = True).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sortino_vol = log_return[log_return<0].rolling(window=trading_days,center=True,min_periods=10).std() * np.sqrt(trading_days)
sortino_ratio = (log_return.rolling(window=trading_days).mean() - Rf)*trading_days / sortino_vol
sortino_vol.plot().update_layout(autosize = False, width=600, height=300).show()
sortino_ratio.plot().update_layout(autosize = False, width=600, height=300).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
m2_ratio = pd.DataFrame()
benchmark_vol = volatility
