# %% [markdown]
# # Market Data Exploration

# %% [markdown]
# Loading in modules

# %%
import datetime as dt
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.offline as pyo
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pyo.init_notebook_mode(connected=True)
pd.options.plotting.backend = "plotly"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
end = dt.datetime(2020, 12, 31)
start = end - dt.timedelta(days=3650)

# %%
stocklist = ["BARC", "HSBA", "LLOY", "NWG"]
stocklist = [stock + ".L" for stock in stocklist]

# %%
df = yf.download(stocklist, start=start, end=end).stack(future_stack=True)
df
# Out:
# [*********************100%***********************]  4 of 4 completed
# Price                   Close        High         Low        Open     Volume
# Date       Ticker
# 2011-01-04 BARC.L  173.051346  173.622319  169.276239  170.323127   52153548
#            HSBA.L  317.099823  318.761026  314.726677  316.008181   21780092
#            LLOY.L   47.037884   47.634178   45.831430   46.254383  182185988
#            NWG.L   319.572388  324.050147  316.587148  318.158340   10133228
# 2011-01-05 BARC.L  178.285751  178.285751  170.672088  172.480337   58927955
# ...                       ...         ...         ...         ...        ...
# 2020-12-29 NWG.L   134.495804  141.247376  134.001827  140.218148   16855647
# 2020-12-30 BARC.L  128.682068  132.315724  128.526481  129.338957   22973899
#            HSBA.L  295.350189  302.020626  294.501920  298.666122   13055106
#            LLOY.L   30.680447   31.359733   30.655440   30.792965  142842833
# ...

# %%
df
# Out:
# Price                   Close        High         Low        Open     Volume
# Date       Ticker
# 2011-01-04 BARC.L  173.051346  173.622319  169.276239  170.323127   52153548
#            HSBA.L  317.099823  318.761026  314.726677  316.008181   21780092
#            LLOY.L   47.037884   47.634178   45.831430   46.254383  182185988
#            NWG.L   319.572388  324.050147  316.587148  318.158340   10133228
# 2011-01-05 BARC.L  178.285751  178.285751  170.672088  172.480337   58927955
# ...                       ...         ...         ...         ...        ...
# 2020-12-29 NWG.L   134.495804  141.247376  134.001827  140.218148   16855647
# 2020-12-30 BARC.L  128.682068  132.315724  128.526481  129.338957   22973899
#            HSBA.L  295.350189  302.020626  294.501920  298.666122   13055106
#            LLOY.L   30.680447   31.359733   30.655440   30.792965  142842833
#            NWG.L   136.307220  138.653772  133.384272  133.384272   10016256
#
# [10104 rows x 5 columns]

# %%
df_barc = df.xs("BARC.L", level=1)
df_barc
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2011-01-04  173.051346  173.622319  169.276239  170.323127  52153548
# 2011-01-05  178.285751  178.285751  170.672088  172.480337  58927955
# 2011-01-06  176.382263  181.204258  175.367110  177.651210  50066406
# 2011-01-07  174.542343  177.968473  174.161632  176.413998  46932032
# 2011-01-10  175.557510  177.619479  173.368530  176.540940  44424703
# ...                ...         ...         ...         ...       ...
# 2020-12-22  126.175499  126.780530  121.888409  122.199570  59502325
# 2020-12-23  131.223221  131.578458  125.259307  125.812480  82164262
# 2020-12-24  133.626068  136.778284  132.526632  133.712494  32838786
# 2020-12-29  129.027786  134.744490  128.612910  133.971778  54336596
# 2020-12-30  128.682068  132.315724  128.526481  129.338957  22973899
#
# [2526 rows x 5 columns]

# %%
df_barc= df_barc.copy()
df_barc["Daily_Return"] = df_barc["Close"] - df_barc["Open"]
df_barc["Daily_Return_Percent"] = (df_barc["Close"] - df_barc["Open"]) / df_barc["Open"] * 100

df_barc["Max_change"] = (df_barc["High"] - df_barc["Low"])
df_barc["Max_change_Percent"] = (df_barc["High"] - df_barc["Low"]) / df_barc["Low"] * 100

df_barc['Open_Close_Diff'] = df_barc['Open'] - df_barc['Close'].shift(1)
df_barc
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2011-01-04  173.051346  173.622319  169.276239  170.323127  52153548
# 2011-01-05  178.285751  178.285751  170.672088  172.480337  58927955
# 2011-01-06  176.382263  181.204258  175.367110  177.651210  50066406
# 2011-01-07  174.542343  177.968473  174.161632  176.413998  46932032
# 2011-01-10  175.557510  177.619479  173.368530  176.540940  44424703
# ...                ...         ...         ...         ...       ...
# 2020-12-22  126.175499  126.780530  121.888409  122.199570  59502325
# 2020-12-23  131.223221  131.578458  125.259307  125.812480  82164262
# 2020-12-24  133.626068  136.778284  132.526632  133.712494  32838786
# 2020-12-29  129.027786  134.744490  128.612910  133.971778  54336596
# 2020-12-30  128.682068  132.315724  128.526481  129.338957  22973899
#
# Price       Daily_Return  Daily_Return_Percent  Max_change  \
# Date
# 2011-01-04      2.728218              1.601790    4.346079
# ...

# %%
df_barc['MA50'] = df_barc['Close'].rolling(window=50, min_periods=0).mean()
df_barc['MA200'] = df_barc['Close'].rolling(window=200, min_periods=0).mean()
df_barc['MA200'].head(30)
# Out:
# Date
# 2011-01-04    173.051346
# 2011-01-05    175.668549
# 2011-01-06    175.906453
# 2011-01-07    175.565426
# 2011-01-10    175.563843
# 2011-01-11    177.180672
# 2011-01-12    179.296317
# 2011-01-13    181.152706
# 2011-01-14    182.949048
# 2011-01-17    184.106949
# 2011-01-18    185.120653
# 2011-01-19    185.352090
# 2011-01-20    185.894440
# 2011-01-21    186.252811
# 2011-01-24    186.546476
# 2011-01-25    186.722143
# 2011-01-26    186.767049
# 2011-01-27    186.944432
# 2011-01-28    187.063073
# 2011-01-31    187.028684
# 2011-02-01    187.141075
# 2011-02-02    187.344187
# 2011-02-03    187.499293
# 2011-02-04    187.831816
# 2011-02-07    188.255750
# 2011-02-08    188.686113
# 2011-02-09    189.132770
# 2011-02-10    189.476147
# 2011-02-11    189.748806
# 2011-02-14    189.995884
# Name: MA200, dtype: float64

# %%
fig = go.Figure()

fig.add_trace(go.Candlestick(x=df_barc.index, open=df_barc["Open"], high=df_barc["High"],
                low=df_barc["Low"], close=df_barc["Close"], name="OHLC"))

fig.update_layout(
    title='BARC historical price chart',
    xaxis_tickfont_size=12,
    yaxis=dict(
        title='Share Price (£))',
        tickfont_size=12,
    ),
    autosize=False,
    width=1600,
    height=1000,
    margin=dict(l=50, r=50, b=50, t=50, pad=2),
    paper_bgcolor='white'
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.add_trace(go.Scatter(x=df_barc.index, y=df_barc["MA50"], marker_color='grey',name="MA50"))
fig.add_trace(go.Scatter(x=df_barc.index, y=df_barc["MA200"], marker_color='black',name="MA200"))

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure(data=[go.Histogram(x=df_barc['Open_Close_Diff'], nbinsx=500, histnorm='probability')])
fig.update_layout(title_text='Open Close Difference Histogram', xaxis_title_text='Open Close Difference', yaxis_title_text='Probability')
fig.update_xaxes(range=[-15,15])

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
